# %% [markdown]
# # Provo ad aprire il geodataframe

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import contextily as ctx

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Regions = gpd.read_file("data/regioni_db/regioni.shp")
Regions.tail(2)
# Out:
#     COD_RIP  COD_REG   DEN_REG    Shape_Leng    Shape_Area  persone  \
# 18        5       19   Sicilia  1.344688e+06  2.582432e+10      330
# 19        5       20  Sardegna  1.449231e+06  2.410630e+10      108
#
#     n_menzione  n_bronzo  n_argento  n_oro  n_medaglie  r_menzione  r_bronzo  \
# 18          68        68         28     13         109    0.206061  0.206061
# 19          25        22          7      3          32    0.231481  0.203704
#
#     r_argento     r_oro  r_medaglie   pos_media  pos_median  \
# 18   0.084848  0.039394    0.330303  178.427273       193.0
# 19   0.064815  0.027778    0.296296  180.916667       187.0
#
#                                              geometry
# 18  MULTIPOLYGON (((822901.365 3935306.722, 822879...
# 19  MULTIPOLYGON (((448813.649 4301762.750, 448823...

# %%
Regions.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1)
Regions.plot(
    ax=ax,
    column="r",
    scheme="equal_interval",
    cmap="YlGn",
    k=10,
    legend=True
)
fig.set_facecolor("LightBlue")
ax.set_axis_off()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1));
