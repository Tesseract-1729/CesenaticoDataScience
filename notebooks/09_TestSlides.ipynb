# %% [markdown]
# # Titolo principale
# ---
# Autore e data

# %% [markdown]
# # Dataset
# - Motivo 1
# - Motivo 2
# - Motivo 3

# %%
5 + 7
# Out:
# 12

# %% [markdown]
# ## Personaggi importanti

# %% [markdown]
# ### Titolo 3

# %% [markdown]
# # Ttitolo della immagine

# %% [markdown]
# ![ahahahaha](/image/MedaglieItalia.svg)

# %% [markdown]
# ![MedaglieItalia.png](attachment:793edaaf-8dbe-4f3d-b95c-6cebb2551ea0.png)

# %% [markdown]
# # Tiloto

# %%
from IPython.display import Image
Image(filename="image/MedaglieItalia.png")

# %% [markdown]
# # Forte
