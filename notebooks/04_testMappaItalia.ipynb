# %% [markdown]
# # Test sui geodataframe

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import contextily as ctx

# %%
reg = gpd.read_file("data/Limiti01012024_g/Limiti01012024_g/Reg01012024_g/Reg01012024_g_WGS84.shp")
reg
# Out:
#     COD_RIP  COD_REG                DEN_REG    Shape_Leng    Shape_Area  \
# 0         1        1               Piemonte  1.234644e+06  2.539164e+10
# 1         1        2          Valle d'Aosta  3.111871e+05  3.258608e+09
# 2         1        3              Lombardia  1.411360e+06  2.386287e+10
# 3         2        4    Trentino-Alto Adige  8.007317e+05  1.360596e+10
# 4         2        5                 Veneto  1.056504e+06  1.835149e+10
# 5         2        6  Friuli-Venezia Giulia  6.593411e+05  7.936834e+09
# 6         1        7                Liguria  8.219165e+05  5.417714e+09
# 7         2        8         Emilia-Romagna  1.176992e+06  2.250182e+10
# 8         3        9                Toscana  1.304650e+06  2.298501e+10
# 9         3       10                 Umbria  6.194046e+05  8.463969e+09
# 10        3       11                 Marche  6.188483e+05  9.344543e+09
# 11        3       12                  Lazio  1.056599e+06  1.723649e+10
# ...

# %%
reg.plot()
# Out:
# <Axes: >
